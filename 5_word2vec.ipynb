# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'a', 'originated', 'term', 'originated', 'term', 'of', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 5000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 25000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.091152
# Nearest to this: freeze, kievan, etc, tabs, brutus, advising, software, rhombicuboctahedron,
# Nearest to th: pid, resistor, probabilistic, careers, felicity, particularity, implanted, heart,
# Nearest to three: grandsons, scholar, palestinian, bullseye, reinstating, maximizing, labeled, knuckles,
# Nearest to were: stateless, jewel, affections, logicians, inflationary, reginald, ophelia, eclac,
# Nearest to first: unavailable, rivalry, improvised, politically, upgraded, caroline, carbide, prokaryotic,
# Nearest to his: carve, batu, leblanc, heater, jed, mcgill, transporter, equate,
# Nearest to that: babe, biloxi, geologist, sybase, insect, mediocre, pula, hedge,
# Nearest to most: kern, electroacoustic, uematsu, injunction, alexanderplatz, yankee, padding, kaplan,
# Nearest to by: involution, eigenvalue, supporting, lagers, reactor, seahawks, america, losing,
# Nearest to not: samarium, quickly, eiga, bendix, kali, ecosystem, neil, flutes,
# Nearest to had: curd, bix, feudalism, trotskyist, michaels, involvement, calibrated, primo,
# Nearest to but: alen, gl, stationed, deviate, documenting, domini, caapi, email,
# Nearest to only: courageous, irrevocably, ponte, spatially, electing, semester, earth, espouse,
# Nearest to its: walley, leffler, megiddo, junior, recanted, phrygian, translucent, racial,
# Nearest to time: eac, decadence, sulfates, puritanism, arianespace, hannity, morgenstern, ahl,
# Nearest to would: sinai, transparent, named, nijmegen, neurology, godly, culminate, homosexuals,
# Average loss at step 2000: 4.361670
# Average loss at step 4000: 3.865796
# Average loss at step 6000: 3.791620
# Average loss at step 8000: 3.686659
# Average loss at step 10000: 3.616314
# Nearest to this: it, the, which, brutus, another, chamada, etc, elia,
# Nearest to th: pid, five, felicity, three, careers, resistor, heart, four,
# Nearest to three: four, eight, six, seven, five, two, nine, zero,
# Nearest to were: are, was, have, reginald, be, would, plough, boutique,
# Nearest to first: caroline, last, politically, hegelians, unavailable, landgrave, armouries, averaging,
# Nearest to his: their, her, the, versions, putin, its, whoever, s,
# Nearest to that: which, babe, geologist, who, it, storming, yucatan, moot,
# Nearest to most: padding, commonly, teh, summits, babes, kern, perched, unabridged,
# Nearest to by: was, within, with, as, octavian, supporting, been, on,
# Nearest to not: also, they, it, still, collagen, we, neil, who,
# Nearest to had: has, have, was, noma, trotskyist, bouldering, emitted, chopsticks,
# Nearest to but: though, documenting, xx, reliever, sangha, poetical, estimate, huygens,
# Nearest to only: let, urey, hoc, qos, baryonic, leak, katanga, eighty,
# Nearest to its: the, their, his, megiddo, baltasar, illustrate, dendritic, each,
# Nearest to time: majesty, offutt, seminary, desolation, purpose, singles, erg, footnotes,
# Nearest to would: can, could, may, sinai, bleed, to, nijmegen, sassanian,
# Average loss at step 12000: 3.600825
# Average loss at step 14000: 3.570074
# Average loss at step 16000: 3.412802
# Average loss at step 18000: 3.458813
# Average loss at step 20000: 3.540401
# Nearest to this: it, which, the, another, brutus, chamada, he, heaps,
# Nearest to th: pid, gascony, five, heart, resistor, felicity, waldo, codifying,
# Nearest to three: seven, four, six, five, two, eight, nine, zero,
# Nearest to were: are, was, have, had, be, is, by, been,
# Nearest to first: caroline, last, politically, anatomical, same, hegelians, averaging, surpluses,
# Nearest to his: their, her, its, the, my, woefully, many, melito,
# Nearest to that: which, but, who, however, babe, gaius, brainstem, this,
# Nearest to most: padding, some, more, babes, laborious, teh, commonly, fibres,
# Nearest to by: through, be, mohammed, within, was, were, in, for,
# Nearest to not: also, still, it, to, they, you, variadic, never,
# Nearest to had: has, have, was, were, operative, collectivist, emitted, buprenorphine,
# Nearest to but: though, however, which, and, that, did, is, there,
# Nearest to only: let, urey, eighty, celebes, wcl, it, hoc, regrouped,
# Nearest to its: their, his, opel, the, her, baltasar, hypothesised, each,
# Nearest to time: majesty, offutt, bernini, fact, purpose, jointly, singles, underrated,
# Nearest to would: could, can, may, will, should, might, deadheads, sinai,
# Average loss at step 22000: 3.503083
# Average loss at step 24000: 3.489007
# Average loss at step 26000: 3.482466
# Average loss at step 28000: 3.479075
# Average loss at step 30000: 3.503437
# Nearest to this: which, it, another, brutus, some, that, any, chronica,
# Nearest to th: six, pid, gascony, four, nd, eight, one, felicity,
# Nearest to three: four, five, seven, eight, six, two, nine, zero,
# Nearest to were: are, was, have, had, been, being, by, be,
# Nearest to first: last, same, second, caroline, anatomical, politically, hegelians, during,
# Nearest to his: her, their, its, the, s, my, tivoli, clips,
# Nearest to that: which, babe, however, this, but, what, because, hedge,
# Nearest to most: more, padding, many, laborious, some, brahmins, kern, fleischmann,
# Nearest to by: under, mohammed, with, were, omission, in, as, disability,
# Nearest to not: still, they, to, often, beauchamp, variadic, sometimes, it,
# Nearest to had: has, have, was, were, operative, having, began, been,
# Nearest to but: however, though, which, although, and, see, while, when,
# Nearest to only: eighty, always, regrouped, about, furthered, yousef, principled, let,
# Nearest to its: their, the, his, her, our, baltasar, wikibook, zetalisp,
# Nearest to time: purpose, intonation, record, singles, majesty, bernini, jointly, piraeus,
# Nearest to would: can, could, may, will, should, might, must, to,
# Average loss at step 32000: 3.498376
# Average loss at step 34000: 3.494328
# Average loss at step 36000: 3.451724
# Average loss at step 38000: 3.307296
# Average loss at step 40000: 3.429134
# Nearest to this: which, it, another, that, the, brutus, some, he,
# Nearest to th: six, gascony, nd, eight, five, seven, gwh, codifying,
# Nearest to three: four, seven, five, six, two, eight, nine, zero,
# Nearest to were: are, have, was, had, been, be, these, being,
# Nearest to first: last, second, caroline, next, anatomical, during, same, despotic,
# Nearest to his: her, their, its, my, s, the, clips, moslem,
# Nearest to that: which, this, however, what, also, honestly, who, brainstem,
# Nearest to most: more, many, laborious, some, padding, fleischmann, less, especially,
# Nearest to by: with, be, supporting, mohammed, exclaims, cerro, angiosperms, for,
# Nearest to not: still, never, they, it, decameron, also, beauchamp, clearly,
# Nearest to had: has, have, was, were, operative, having, publicizing, bowden,
# Nearest to but: however, though, and, although, are, which, fortunately, he,
# Nearest to only: normally, always, marcantonio, it, lager, eighty, urey, firms,
# Nearest to its: their, his, her, the, our, industrious, lunar, baltasar,
# Nearest to time: year, bernini, perrault, intonation, jointly, abramovich, singles, jia,
# Nearest to would: will, can, could, may, should, might, must, did,
# Average loss at step 42000: 3.434298
# Average loss at step 44000: 3.449785
# Average loss at step 46000: 3.450805
# Average loss at step 48000: 3.351334
# Average loss at step 50000: 3.384563
# Nearest to this: which, it, the, that, another, some, itself, there,
# Nearest to th: gascony, one, nd, eight, six, pid, searches, outweighs,
# Nearest to three: six, seven, four, eight, two, five, nine, zero,
# Nearest to were: are, have, was, had, being, been, be, although,
# Nearest to first: last, second, next, same, caroline, during, recreational, best,
# Nearest to his: her, their, its, my, your, the, our, him,
# Nearest to that: which, however, this, veteran, schumacher, brainstem, fisa, honestly,
# Nearest to most: more, many, laborious, some, less, fleischmann, jacketed, brahmins,
# Nearest to by: under, was, through, mohammed, with, as, for, disability,
# Nearest to not: never, they, still, usually, normally, beauchamp, clearly, variadic,
# Nearest to had: has, have, was, having, were, operative, since, ever,
# Nearest to but: however, though, although, and, when, while, which, he,
# Nearest to only: normally, always, lager, zut, already, either, amazigh, siding,
# Nearest to its: their, his, the, her, our, baltasar, my, lunar,
# Nearest to time: year, way, vampyre, stride, jia, intonation, period, maneuvering,
# Nearest to would: will, could, may, can, should, might, must, does,
# Average loss at step 52000: 3.436101
# Average loss at step 54000: 3.429108
# Average loss at step 56000: 3.441331
# Average loss at step 58000: 3.393129
# Average loss at step 60000: 3.395076
# Nearest to this: which, it, that, another, there, occur, itself, some,
# Nearest to th: five, gascony, one, six, nd, eight, gwh, four,
# Nearest to three: five, four, seven, six, eight, two, nine, zero,
# Nearest to were: are, had, have, was, those, although, including, surveyors,
# Nearest to first: second, last, next, caroline, only, same, hugs, final,
# Nearest to his: her, their, my, its, woefully, your, our, jesus,
# Nearest to that: which, this, however, what, it, honestly, readily, psychometric,
# Nearest to most: many, more, some, laborious, use, especially, less, bray,
# Nearest to by: mohammed, through, with, disability, under, from, omission, when,
# Nearest to not: still, they, usually, normally, never, you, immediately, beauchamp,
# Nearest to had: has, have, was, were, having, operative, knew, been,
# Nearest to but: however, although, though, and, when, than, see, materialism,
# Nearest to only: normally, always, first, zut, already, cheating, until, still,
# Nearest to its: their, his, the, her, our, cachet, your, whose,
# Nearest to time: year, intonation, period, vampyre, way, maneuvering, case, fact,
# Nearest to would: will, could, may, can, should, might, must, does,
# Average loss at step 62000: 3.243222
# Average loss at step 64000: 3.252015
# Average loss at step 66000: 3.406037
# Average loss at step 68000: 3.394054
# Average loss at step 70000: 3.363513
# Nearest to this: which, it, that, another, the, some, there, itself,
# Nearest to th: gascony, bc, twentieth, nd, six, bce, waldo, kryptonite,
# Nearest to three: two, four, six, five, seven, eight, nine, zero,
# Nearest to were: are, was, have, had, be, been, although, those,
# Nearest to first: second, last, next, caroline, third, same, final, hugs,
# Nearest to his: her, their, its, my, your, tivoli, our, whose,
# Nearest to that: which, however, what, but, this, unsuitable, often, mandated,
# Nearest to most: more, many, less, some, use, especially, occultation, padding,
# Nearest to by: through, mohammed, using, from, be, disability, under, fully,
# Nearest to not: still, normally, usually, never, they, always, now, also,
# Nearest to had: has, have, was, were, having, since, knew, been,
# Nearest to but: however, although, though, and, which, that, grudge, while,
# Nearest to only: normally, always, zut, still, not, already, lonergan, legally,
# Nearest to its: their, his, her, the, our, whose, sprite, amathus,
# Nearest to time: vampyre, way, case, period, stride, fact, maneuvering, place,
# Nearest to would: will, could, may, can, might, should, must, does,
# Average loss at step 72000: 3.371622
# Average loss at step 74000: 3.344733
# Average loss at step 76000: 3.308718
# Average loss at step 78000: 3.354131
# Average loss at step 80000: 3.377158
# Nearest to this: which, it, another, what, the, itself, ids, memberships,
# Nearest to th: gascony, twentieth, bc, four, nd, waldo, bce, five,
# Nearest to three: six, four, five, eight, two, seven, nine, zero,
# Nearest to were: are, was, had, have, being, been, those, although,
# Nearest to first: second, last, next, third, caroline, same, final, previous,
# Nearest to his: her, their, its, my, your, our, tivoli, woefully,
# Nearest to that: which, however, brainstem, where, readily, pompeii, honestly, rarely,
# Nearest to most: many, more, some, less, especially, fleischmann, occultation, babes,
# Nearest to by: mohammed, through, disability, when, and, using, reactor, under,
# Nearest to not: still, usually, we, normally, never, they, generally, always,
# Nearest to had: have, has, was, were, having, operative, been, gave,
# Nearest to but: however, although, though, and, than, which, assassinating, sustenance,
# Nearest to only: always, zut, normally, last, chatham, currently, menachem, already,
# Nearest to its: their, his, her, our, your, the, whose, my,
# Nearest to time: vampyre, year, stride, smoked, round, place, singles, period,
# Nearest to would: will, could, may, can, might, should, must, did,
# Average loss at step 82000: 3.407794
# Average loss at step 84000: 3.409896
# Average loss at step 86000: 3.392066
# Average loss at step 88000: 3.353635
# Average loss at step 90000: 3.363228
# Nearest to this: it, which, the, brutus, some, another, itself, ids,
# Nearest to th: twentieth, gascony, seven, bc, one, nd, waldo, eight,
# Nearest to three: five, two, four, six, seven, eight, nine, zero,
# Nearest to were: are, was, had, while, have, although, being, remain,
# Nearest to first: second, last, next, caroline, final, third, earliest, reissues,
# Nearest to his: her, their, its, my, your, our, the, woefully,
# Nearest to that: which, however, babe, what, but, where, whom, veteran,
# Nearest to most: more, less, especially, many, some, use, tiles, several,
# Nearest to by: through, under, mohammed, disability, for, when, without, while,
# Nearest to not: still, never, we, also, generally, now, almost, usually,
# Nearest to had: has, have, was, were, having, operative, would, bowden,
# Nearest to but: however, and, although, though, he, until, while, they,
# Nearest to only: normally, zut, any, always, even, already, menachem, no,
# Nearest to its: their, his, her, the, our, your, whose, confessing,
# Nearest to time: vampyre, period, stride, year, way, singles, flight, place,
# Nearest to would: will, could, might, may, can, must, should, did,
# Average loss at step 92000: 3.397866
# Average loss at step 94000: 3.254359
# Average loss at step 96000: 3.358068
# Average loss at step 98000: 3.247134
# Average loss at step 100000: 3.360092
# Nearest to this: it, which, what, itself, some, brutus, another, there,
# Nearest to th: twentieth, bc, gascony, nd, one, third, second, signaled,
# Nearest to three: four, five, six, eight, seven, two, nine, zero,
# Nearest to were: are, have, was, had, these, although, those, include,
# Nearest to first: last, second, next, third, final, fourth, previous, caroline,
# Nearest to his: her, their, my, your, our, its, the, s,
# Nearest to that: which, however, what, brainstem, who, why, this, whom,
# Nearest to most: more, less, especially, many, quite, some, occultation, use,
# Nearest to by: mohammed, under, through, when, using, disability, without, separating,
# Nearest to not: never, still, almost, normally, now, they, considered, generally,
# Nearest to had: has, have, was, were, would, having, knew, since,
# Nearest to but: however, although, and, though, which, while, truss, did,
# Nearest to only: normally, already, zut, always, menachem, till, either, cheating,
# Nearest to its: their, his, her, the, our, your, whose, curiae,
# Nearest to time: way, singles, place, stride, year, vampyre, period, approve,
# Nearest to would: will, could, might, may, can, should, must, did,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
# %matplotlib inline

def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    batch_slice = batch_size + 2 * skip_window
    batches = np.ndarray(shape=(batch_size, 2 * skip_window), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    current_batch = data[data_index:data_index + batch_slice]
    span = 2 * skip_window + 1
    
    for i in range(batch_size):
        window = current_batch[i:i + span]
        target_index = int(len(window) / 2)
        labels[i, 0] = window[target_index]
        batch_idx = 0
    
        for j in range(1, skip_window + 1):
            batches[i, batch_idx] = window[target_index - j]
            batch_idx += 1
            batches[i, batch_idx] = window[target_index + j]
            batch_idx += 1
    
    data_index += batch_slice

    if data_index > len(data):
        data_index = 0
    
    return batches, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('batch:', [[reverse_dictionary[bi2] for bi2 in bi] for bi in batch])
    print('labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
# batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
# labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 4 and skip_window = 2:
# batch: [['originated', 'a', 'anarchism', 'term'], ['as', 'term', 'originated', 'of'], ['a', 'of', 'as', 'abuse'], ['term', 'abuse', 'a', 'first'], ['of', 'first', 'term', 'used'], ['abuse', 'used', 'of', 'against'], ['first', 'against', 'abuse', 'early'], ['used', 'early', 'first', 'working']]
# labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
# General properties
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector
skip_window = 1 # How many words to consider left and right
num_skips = 2 # How many times to reuse an input to generate a label
num_sampled = 64 # Number of negative examples to sample

# Validation properties
valid_size = 16 # Random set of words to evaluate similarity on
valid_window = 100 # Only pick dev samples in the head of the distribution
valid_examples = np.array(random.sample(range(valid_window), valid_size))

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
    # Training and validation
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, num_skips])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Embedding, weights, and biases
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset[:,0]) + tf.nn.embedding_lookup(embeddings, train_dataset[:,1])
    
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed, train_labels, num_sampled, vocabulary_size))
    
    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute the similarity between minibatch examples and all embeddings. We use the cosine distance
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    average_loss = 0

    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 25000 == 0:
            sim = similarity.eval()
            
            print('Step: ' + str(step))
            
            for i in xrange(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                
                for k in xrange(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                
                print(log)
                
            print('')
    
    final_embeddings = normalized_embeddings.eval()
# Out:
# Step: 0
# Nearest to been: terminal, representational, propounded, nucleotides, mounds, delivered, yuga, cogency,
# Nearest to first: faramir, anaesthetic, repaired, parse, phenotypes, ventures, alam, cmyk,
# Nearest to up: timpani, reification, cth, rendezvous, resupply, pxe, notebooks, teeming,
# Nearest to while: odrade, bord, recombine, ara, insulin, wtro, murdered, taraza,
# Nearest to his: lys, charting, escorial, barn, pisces, waterproof, eoin, joris,
# Nearest to by: sensitivities, kurdistan, unaids, batavians, chinaman, globin, extremity, mesh,
# Nearest to and: olympiad, pomeranian, bacilli, humorous, cohabitation, anacharsis, generally, oaxaca,
# Nearest to no: fayette, grief, asher, brava, wednesday, sniff, imprinted, other,
# Nearest to other: eccentricity, columbians, placenames, wedge, ramanujan, clinic, no, conceptions,
# Nearest to UNK: dyslexia, ostracized, magazine, trailer, romanesque, mackerel, falkland, rearguard,
# Nearest to of: neberg, krone, ck, dah, specialize, escalating, parque, bayou,
# Nearest to seven: bacteria, sextet, aristides, warping, airing, ferdinand, thermopylae, engenders,
# Nearest to on: eccentricities, keynesianism, dorm, langer, litre, trades, stanford, shorelines,
# Nearest to with: mafiosi, doha, prix, inflicting, enso, tortoise, inherits, superscript,
# Nearest to such: reductive, amstrad, fishers, coordinator, ladyland, demoscene, assisting, watford,
# Nearest to not: aarhus, vf, ink, goyen, avl, cobain, rackham, marjorie,
#
# Step: 25000
# Nearest to been: become, be, was, tagalog, being, were, colecovision, fixture,
# Nearest to first: last, second, obscenity, next, gormenghast, tudor, entire, same,
# Nearest to up: out, off, them, notebooks, thor, down, him, rendezvous,
# Nearest to while: when, however, although, towards, during, after, though, through,
# Nearest to his: their, her, its, my, your, our, savory, relies,
# Nearest to by: batavians, with, roleplaying, lodge, during, duval, into, breach,
# Nearest to and: or, but, gab, leone, lumpur, ips, which, atchison,
# Nearest to no: any, wednesday, a, sporty, panza, headline, declarations, some,
# Nearest to other: different, offset, stealth, scope, various, reruns, latinos, functors,
# Nearest to UNK: breakbeat, systemic, diagonals, sunga, bruges, avant, ecoregion, dkw,
# Nearest to of: in, for, where, barbagia, ryu, reentry, ramp, runic,
# Nearest to seven: eight, six, nine, five, four, zero, three, two,
# Nearest to on: upon, through, in, during, within, litre, around, kept,
# Nearest to with: between, including, by, while, mutualism, displace, through, vegetarianism,
# Nearest to such: these, well, known, served, doctoral, vestiges, many, knuth,
# Nearest to not: usually, generally, still, nawab, midgard, mantras, also, lrv,
#
# Step: 50000
# Nearest to been: become, already, be, was, replacing, previously, hermeticism, ever,
# Nearest to first: last, second, next, original, fourth, best, same, third,
# Nearest to up: off, out, him, together, them, notebooks, down, sail,
# Nearest to while: although, when, though, after, but, casually, however, before,
# Nearest to his: her, their, my, its, our, your, the, s,
# Nearest to by: when, drpg, lodge, haeckel, batavians, erect, through, annuity,
# Nearest to and: or, but, american, including, tswana, gab, quranic, nancy,
# Nearest to no: any, only, silla, biog, sniff, declarations, headline, touching,
# Nearest to other: different, ebbets, others, individual, various, cosets, contributors, older,
# Nearest to UNK: poet, lately, explorer, et, politician, arthur, lindsay, philip,
# Nearest to of: in, consecutively, including, carib, concurrency, posse, during, laurier,
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Nearest to on: upon, in, fricative, about, through, concerning, denote, cahokia,
# Nearest to with: between, including, using, mutualism, ly, like, umm, combatant,
# Nearest to such: well, known, these, abbe, regarded, served, defined, including,
# Nearest to not: still, now, generally, never, mantras, actually, t, almost,
#
# Step: 75000
# Nearest to been: become, be, already, was, fallen, scaly, were, cayuga,
# Nearest to first: last, next, second, best, third, earliest, fourth, original,
# Nearest to up: off, out, down, together, them, him, back, sail,
# Nearest to while: although, though, when, however, after, before, but, casually,
# Nearest to his: her, their, its, my, our, your, whose, the,
# Nearest to by: during, batavians, addiction, with, erect, through, rearrange, lillehammer,
# Nearest to and: or, but, gab, although, including, like, welcoming, wishful,
# Nearest to no: any, homily, editorials, another, little, synonymous, heterosexuality, stonehenge,
# Nearest to other: various, fewer, individual, different, unionism, ebbets, unresponsive, alfa,
# Nearest to UNK: dedham, graf, phagocytosis, raining, ecoregion, romita, yue, brancusi,
# Nearest to of: in, barbagia, magnate, allowance, logics, laurier, essences, including,
# Nearest to seven: eight, six, four, five, nine, three, zero, two,
# Nearest to on: upon, concerning, through, in, around, under, within, ap,
# Nearest to with: between, mutualism, pacifists, combatant, among, umm, by, purchasers,
# Nearest to such: well, known, certain, these, defined, described, serve, specific,
# Nearest to not: never, still, now, actually, usually, almost, mantras, always,
#
# Step: 100000
# Nearest to been: become, be, already, were, fallen, scaly, remained, traditionally,
# Nearest to first: last, second, next, fourth, third, best, earliest, final,
# Nearest to up: off, out, down, together, back, notebooks, sail, him,
# Nearest to while: although, when, before, though, after, but, began, upheavals,
# Nearest to his: their, her, its, my, your, our, the, whose,
# Nearest to by: through, when, popularize, baruch, including, drpg, regimental, amphibian,
# Nearest to and: but, or, gab, including, utilitarian, however, docherty, tswana,
# Nearest to no: little, any, biog, synonymous, concerned, another, editorials, stifle,
# Nearest to other: various, individual, others, unionism, rivets, loti, retrospect, eschatological,
# Nearest to UNK: autonomously, eckhart, uppsala, weidman, spotting, locke, generalize, graphite,
# Nearest to of: whose, markschies, lodovico, including, yielding, despite, cadr, from,
# Nearest to seven: eight, nine, five, six, four, three, zero, two,
# Nearest to on: upon, concerning, within, evaporate, in, around, secant, regarding,
# Nearest to with: between, umm, jumpers, mutualism, displace, ly, coupe, overlooking,
# Nearest to such: well, these, known, few, certain, serve, abbe, themselves,
# Nearest to not: never, actually, always, still, mantras, generally, now, nor,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
# %matplotlib inline

def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
